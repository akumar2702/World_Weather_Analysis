# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)

#     # Log the URL, record, and set numbers and the city.
#     print(f"Processing Record {record_count} of Set {set_count} | {city}")
#     # Add 1 to the record count.
#     record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        print(city.title())
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})
                          
# If an error is experienced, skip the city.
    except:
                          
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=ahipara
# {'coord': {'lon': 173.1667, 'lat': -35.1667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.45, 'feels_like': 75.18, 'temp_min': 75.45, 'temp_max': 75.45, 'pressure': 1018, 'humidity': 53, 'sea_level': 1018, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 12.75, 'deg': 71, 'gust': 19.84}, 'clouds': {'all': 97}, 'dt': 1643582030, 'sys': {'country': 'NZ', 'sunrise': 1643564688, 'sunset': 1643614585}, 'timezone': 46800, 'id': 2194098, 'name': 'Ahipara', 'cod': 200}
# Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 80.55, 'feels_like': 84.61, 'temp_min': 80.55, 'temp_max': 80.55, 'pressure': 1012, 'humidity': 75, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 12.12, 'deg': 99, 'gust': 12.91}, 'rain': {'1h': 0.31}, 'clouds': {'all': 100}, 'dt': 1643582030, 'sys': {'country': 'TO', 'sunrise': 1643649767, 'sunset': 1643696741}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=lorengau
# {'coord': {'lon': 147.2712, 'lat': -2.0226}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.09, 'feels_like': 79.09, 'temp_min': 79.09, 'temp_max': 79.09, 'pressure': 1009, 'humidity': 85, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 12.95, 'deg': 284, 'gust': 16.35}, 'clouds': {'all': 100}, 'dt': 1643581994, 'sys': {'country': 'PG', 'sunrise': 1643573890, 'sunset': 1643617814}, 'timezone': 36000, 'id': 2092164, 'name': 'Lorengau', 'cod': 200}
# Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 46.06, 'feels_like': 36.7, 'temp_min': 46.06, 'temp_max': 46.06, 'pressure': 999, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 29.93, 'deg': 230, 'gust': 41.43}, 'clouds': {'all': 75}, 'dt': 1643582030, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1643532754, 'sunset': 1643589616}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=sao+jose+da+coroa+grande
# {'coord': {'lon': -35.1478, 'lat': -8.8978}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.2, 'feels_like': 79.2, 'temp_min': 79.2, 'temp_max': 79.2, 'pressure': 1013, 'humidity': 80, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 8.32, 'deg': 94, 'gust': 13.13}, 'clouds': {'all': 88}, 'dt': 1643582030, 'sys': {'country': 'BR', 'sunrise': 1643530731, 'sunset': 1643575725}, 'timezone': -10800, 'id': 3388456, 'name': 'São José da Coroa Grande', 'cod': 200}
# Sao Jose Da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=ancud
# {'coord': {'lon': -73.8203, 'lat': -41.8697}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 62.13, 'feels_like': 60.82, 'temp_min': 59.43, 'temp_max': 62.13, 'pressure': 1021, 'humidity': 59, 'sea_level': 1021, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 10.94, 'deg': 222, 'gust': 13.29}, 'clouds': {'all': 35}, 'dt': 1643582031, 'sys': {'type': 1, 'id': 8512, 'country': 'CL', 'sunrise': 1643536648, 'sunset': 1643588372}, 'timezone': -10800, 'id': 3899695, 'name': 'Ancud', 'cod': 200}
# Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=machala
# {'coord': {'lon': -79.9667, 'lat': -3.2667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 82.35, 'feels_like': 85.96, 'temp_min': 80.91, 'temp_max': 82.35, 'pressure': 1010, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 320}, 'rain': {'1h': 0.38}, 'clouds': {'all': 75}, 'dt': 1643582031, 'sys': {'type': 1, 'id': 8539, 'country': 'EC', 'sunrise': 1643541927, 'sunset': 1643586044}, 'timezone': -18000, 'id': 3654533, 'name': 'Machala', 'cod': 200}
# Machala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.12, 'feels_like': 69.87, 'temp_min': 68.29, 'temp_max': 69.12, 'pressure': 1014, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 170}, 'clouds': {'all': 87}, 'dt': 1643582031, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1643601540, 'sunset': 1643651242}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=nikolskoye
# {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 26.08, 'feels_like': 19.44, 'temp_min': 25.81, 'temp_max': 27.39, 'pressure': 990, 'humidity': 96, 'sea_level': 990, 'grnd_level': 986}, 'visibility': 620, 'wind': {'speed': 5.7, 'deg': 88, 'gust': 16.73}, 'snow': {'1h': 1}, 'clouds': {'all': 100}, 'dt': 1643582032, 'sys': {'type': 2, 'id': 47750, 'country': 'RU', 'sunrise': 1643609521, 'sunset': 1643638103}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=roxas
# {'coord': {'lon': 122.7511, 'lat': 11.5853}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.04, 'feels_like': 79.45, 'temp_min': 78.04, 'temp_max': 78.04, 'pressure': 1012, 'humidity': 83, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 4.18, 'deg': 19, 'gust': 6.46}, 'clouds': {'all': 53}, 'dt': 1643582032, 'sys': {'country': 'PH', 'sunrise': 1643580813, 'sunset': 1643622662}, 'timezone': 28800, 'id': 1691444, 'name': 'Roxas', 'cod': 200}
# Roxas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=arraial+do+cabo
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.86, 'feels_like': 78.39, 'temp_min': 76.86, 'temp_max': 76.86, 'pressure': 1010, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 90}, 'clouds': {'all': 75}, 'dt': 1643582032, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1643531191, 'sunset': 1643578567}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Arraial Do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=cape+town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68.16, 'feels_like': 68.31, 'temp_min': 65.1, 'temp_max': 73.81, 'pressure': 1010, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 0, 'gust': 4}, 'clouds': {'all': 0}, 'dt': 1643581887, 'sys': {'type': 2, 'id': 2033665, 'country': 'ZA', 'sunrise': 1643601999, 'sunset': 1643651559}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=tazovskiy
# {'coord': {'lon': 78.7, 'lat': 67.4667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -10.37, 'feels_like': -22.97, 'temp_min': -10.37, 'temp_max': -10.37, 'pressure': 1024, 'humidity': 99, 'sea_level': 1024, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 8.52, 'deg': 143, 'gust': 13.89}, 'clouds': {'all': 99}, 'dt': 1643582032, 'sys': {'country': 'RU', 'sunrise': 1643601729, 'sunset': 1643622893}, 'timezone': 18000, 'id': 1489853, 'name': 'Tazovsky', 'cod': 200}
# Tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 64.69, 'feels_like': 64.47, 'temp_min': 58.86, 'temp_max': 72.1, 'pressure': 1010, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 290}, 'clouds': {'all': 20}, 'dt': 1643582019, 'sys': {'type': 2, 'id': 2011256, 'country': 'AU', 'sunrise': 1643569851, 'sunset': 1643621825}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63.25, 'feels_like': 63.88, 'temp_min': 63.25, 'temp_max': 63.25, 'pressure': 1011, 'humidity': 98, 'sea_level': 1011, 'grnd_level': 900}, 'visibility': 10000, 'wind': {'speed': 9.19, 'deg': 75, 'gust': 21.79}, 'clouds': {'all': 98}, 'dt': 1643582033, 'sys': {'country': 'BR', 'sunrise': 1643532936, 'sunset': 1643580655}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=punta+arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.91, 'feels_like': 49.15, 'temp_min': 51.12, 'temp_max': 51.91, 'pressure': 1004, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 23.02, 'deg': 250}, 'clouds': {'all': 75}, 'dt': 1643581788, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1643533809, 'sunset': 1643589817}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=new+norfolk
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 65.48, 'feels_like': 64.54, 'temp_min': 58.5, 'temp_max': 71.74, 'pressure': 1011, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 2.62, 'deg': 9, 'gust': 4.03}, 'clouds': {'all': 3}, 'dt': 1643581984, 'sys': {'type': 2, 'id': 2031307, 'country': 'AU', 'sunrise': 1643569931, 'sunset': 1643621875}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=skagastrond
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=wabag
# {'coord': {'lon': 143.7021, 'lat': -5.4781}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 59.85, 'feels_like': 59.58, 'temp_min': 59.85, 'temp_max': 59.85, 'pressure': 1014, 'humidity': 86, 'sea_level': 1014, 'grnd_level': 783}, 'visibility': 10000, 'wind': {'speed': 2.35, 'deg': 214, 'gust': 4.74}, 'clouds': {'all': 98}, 'dt': 1643581953, 'sys': {'country': 'PG', 'sunrise': 1643574483, 'sunset': 1643618935}, 'timezone': 36000, 'id': 2084246, 'name': 'Wabag', 'cod': 200}
# Wabag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=fairbanks
# {'coord': {'lon': -147.7164, 'lat': 64.8378}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': -14.98, 'feels_like': -14.98, 'temp_min': -23.8, 'temp_max': -7.76, 'pressure': 1025, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1643581863, 'sys': {'type': 1, 'id': 7684, 'country': 'US', 'sunrise': 1643568158, 'sunset': 1643592336}, 'timezone': -32400, 'id': 5861897, 'name': 'Fairbanks', 'cod': 200}
# Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=begoro
# {'coord': {'lon': -0.3774, 'lat': 6.3871}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.71, 'feels_like': 70.09, 'temp_min': 71.71, 'temp_max': 71.71, 'pressure': 1012, 'humidity': 32, 'sea_level': 1012, 'grnd_level': 959}, 'visibility': 10000, 'wind': {'speed': 2.33, 'deg': 161, 'gust': 2.62}, 'clouds': {'all': 100}, 'dt': 1643582034, 'sys': {'country': 'GH', 'sunrise': 1643523562, 'sunset': 1643566202}, 'timezone': 0, 'id': 2303236, 'name': 'Begoro', 'cod': 200}
# Begoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=guadalupe+y+calvo
# {'coord': {'lon': -106.9667, 'lat': 26.1}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 53.62, 'feels_like': 50.18, 'temp_min': 53.62, 'temp_max': 53.62, 'pressure': 1016, 'humidity': 32, 'sea_level': 1016, 'grnd_level': 773}, 'visibility': 10000, 'wind': {'speed': 12.88, 'deg': 244, 'gust': 23.17}, 'clouds': {'all': 43}, 'dt': 1643582034, 'sys': {'country': 'MX', 'sunrise': 1643550775, 'sunset': 1643590157}, 'timezone': -25200, 'id': 4005370, 'name': 'Guadalupe y Calvo', 'cod': 200}
# Guadalupe Y Calvo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 8.76, 'feels_like': -3.84, 'temp_min': 8.76, 'temp_max': 8.76, 'pressure': 1013, 'humidity': 53, 'sea_level': 1013, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 10.58, 'deg': 319, 'gust': 14.25}, 'clouds': {'all': 97}, 'dt': 1643582034, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1643542224, 'sunset': 1643565426}, 'timezone': -10800, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=souillac
# {'coord': {'lon': 57.5167, 'lat': -20.5167}, 'weather': [{'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 79.18, 'feels_like': 79.18, 'temp_min': 78.37, 'temp_max': 79.18, 'pressure': 1009, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 160}, 'rain': {'1h': 0.49}, 'clouds': {'all': 75}, 'dt': 1643582035, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1643593951, 'sunset': 1643640841}, 'timezone': 14400, 'id': 933995, 'name': 'Souillac', 'cod': 200}
# Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 71.47, 'feels_like': 71.04, 'temp_min': 71.47, 'temp_max': 71.47, 'pressure': 1022, 'humidity': 58, 'sea_level': 1022, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 1.7, 'deg': 219, 'gust': 2.24}, 'clouds': {'all': 46}, 'dt': 1643581806, 'sys': {'type': 2, 'id': 2008959, 'country': 'NZ', 'sunrise': 1643564135, 'sunset': 1643617203}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=kisanga
# {'coord': {'lon': 37.7034, 'lat': -7.4362}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 72.99, 'feels_like': 74.59, 'temp_min': 72.99, 'temp_max': 72.99, 'pressure': 1010, 'humidity': 98, 'sea_level': 1010, 'grnd_level': 993}, 'visibility': 10000, 'wind': {'speed': 2.33, 'deg': 54, 'gust': 8.01}, 'rain': {'1h': 0.63}, 'clouds': {'all': 99}, 'dt': 1643582035, 'sys': {'country': 'TZ', 'sunrise': 1643599777, 'sunset': 1643644526}, 'timezone': 10800, 'id': 157014, 'name': 'Kisanga', 'cod': 200}
# Kisanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=mahibadhoo
# {'coord': {'lon': 72.9667, 'lat': 3.7833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.86, 'feels_like': 87.28, 'temp_min': 81.86, 'temp_max': 81.86, 'pressure': 1008, 'humidity': 75, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 13.06, 'deg': 78, 'gust': 13.24}, 'clouds': {'all': 64}, 'dt': 1643582035, 'sys': {'country': 'MV', 'sunrise': 1643592164, 'sunset': 1643635211}, 'timezone': 18000, 'id': 1337605, 'name': 'Mahibadhoo', 'cod': 200}
# Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=kaitangata
# {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 70.93, 'feels_like': 71.15, 'temp_min': 70.93, 'temp_max': 70.93, 'pressure': 1022, 'humidity': 73, 'sea_level': 1022, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 3.38, 'deg': 106, 'gust': 2.84}, 'clouds': {'all': 17}, 'dt': 1643581819, 'sys': {'type': 2, 'id': 2000217, 'country': 'NZ', 'sunrise': 1643563884, 'sunset': 1643616983}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=prince+rupert
# {'coord': {'lon': -130.3201, 'lat': 54.3161}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 37.49, 'feels_like': 33.85, 'temp_min': 37.49, 'temp_max': 38.89, 'pressure': 1010, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 150}, 'clouds': {'all': 100}, 'dt': 1643582036, 'sys': {'type': 1, 'id': 883, 'country': 'CA', 'sunrise': 1643560355, 'sunset': 1643591789}, 'timezone': -28800, 'id': 6113406, 'name': 'Prince Rupert', 'cod': 200}
# Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=izazi
# {'coord': {'lon': 35.7333, 'lat': -7.2}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 70.23, 'feels_like': 71.37, 'temp_min': 70.23, 'temp_max': 70.23, 'pressure': 1010, 'humidity': 94, 'sea_level': 1010, 'grnd_level': 929}, 'visibility': 10000, 'wind': {'speed': 0.87, 'deg': 60, 'gust': 2.35}, 'rain': {'1h': 1.39}, 'clouds': {'all': 100}, 'dt': 1643582036, 'sys': {'country': 'TZ', 'sunrise': 1643600268, 'sunset': 1643644980}, 'timezone': 10800, 'id': 158825, 'name': 'Izazi', 'cod': 200}
# Izazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=matara
# {'coord': {'lon': 80.5353, 'lat': 5.9485}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 74.57, 'feels_like': 76.1, 'temp_min': 74.57, 'temp_max': 74.57, 'pressure': 1009, 'humidity': 93, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 5.55, 'deg': 40, 'gust': 5.91}, 'clouds': {'all': 33}, 'dt': 1643582036, 'sys': {'country': 'LK', 'sunrise': 1643590511, 'sunset': 1643633230}, 'timezone': 19800, 'id': 1235846, 'name': 'Matara', 'cod': 200}
# Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=port+blair
# {'coord': {'lon': 92.75, 'lat': 11.6667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 71.37, 'feels_like': 71.58, 'temp_min': 71.37, 'temp_max': 71.37, 'pressure': 1010, 'humidity': 72, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.87, 'deg': 15, 'gust': 7.67}, 'clouds': {'all': 34}, 'dt': 1643582037, 'sys': {'country': 'IN', 'sunrise': 1643588019, 'sunset': 1643629858}, 'timezone': 19800, 'id': 1259385, 'name': 'Port Blair', 'cod': 200}
# Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=esperance
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 66.04, 'feels_like': 66.11, 'temp_min': 66.04, 'temp_max': 66.04, 'pressure': 1012, 'humidity': 80, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 16.6, 'deg': 154, 'gust': 17.27}, 'clouds': {'all': 38}, 'dt': 1643582037, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1643577154, 'sunset': 1643626730}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 82.11, 'feels_like': 88.05, 'temp_min': 82.11, 'temp_max': 82.11, 'pressure': 1009, 'humidity': 76, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 20.94, 'deg': 64, 'gust': 23.51}, 'clouds': {'all': 22}, 'dt': 1643582037, 'sys': {'country': 'KI', 'sunrise': 1643568151, 'sunset': 1643611303}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=ginir
# {'coord': {'lon': 40.7, 'lat': 7.1333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 56.52, 'feels_like': 52.75, 'temp_min': 56.52, 'temp_max': 56.52, 'pressure': 1014, 'humidity': 19, 'sea_level': 1014, 'grnd_level': 809}, 'visibility': 10000, 'wind': {'speed': 5.03, 'deg': 343, 'gust': 5.21}, 'clouds': {'all': 83}, 'dt': 1643582038, 'sys': {'country': 'ET', 'sunrise': 1643600162, 'sunset': 1643642702}, 'timezone': 10800, 'id': 336454, 'name': 'Ginir', 'cod': 200}
# Ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=hithadhoo
# {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.55, 'feels_like': 85.6, 'temp_min': 81.55, 'temp_max': 81.55, 'pressure': 1008, 'humidity': 70, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 8.93, 'deg': 48, 'gust': 8.61}, 'clouds': {'all': 76}, 'dt': 1643582038, 'sys': {'country': 'MV', 'sunrise': 1643591805, 'sunset': 1643635513}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=leningradskiy
# {'coord': {'lon': 178.4167, 'lat': 69.3833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -14.48, 'feels_like': -25.04, 'temp_min': -14.48, 'temp_max': -14.48, 'pressure': 1033, 'humidity': 95, 'sea_level': 1033, 'grnd_level': 1033}, 'visibility': 10000, 'wind': {'speed': 3.74, 'deg': 155, 'gust': 3.76}, 'clouds': {'all': 81}, 'dt': 1643582038, 'sys': {'country': 'RU', 'sunrise': 1643579449, 'sunset': 1643597303}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=nara
# {'coord': {'lon': 135.8049, 'lat': 34.6851}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 34.07, 'feels_like': 34.07, 'temp_min': 32.7, 'temp_max': 36.64, 'pressure': 1019, 'humidity': 75, 'sea_level': 1019, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 2.59, 'deg': 330, 'gust': 7.72}, 'clouds': {'all': 21}, 'dt': 1643582039, 'sys': {'type': 2, 'id': 20513, 'country': 'JP', 'sunrise': 1643579769, 'sunset': 1643617439}, 'timezone': 32400, 'id': 1855612, 'name': 'Nara', 'cod': 200}
# Nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 68.81, 'feels_like': 69.44, 'temp_min': 68.81, 'temp_max': 71.91, 'pressure': 1012, 'humidity': 86, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 12.84, 'deg': 91, 'gust': 21.14}, 'clouds': {'all': 97}, 'dt': 1643582019, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1643601747, 'sunset': 1643651422}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=zhigansk
# {'coord': {'lon': 123.3711, 'lat': 66.7697}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -33.23, 'feels_like': -33.23, 'temp_min': -33.23, 'temp_max': -33.23, 'pressure': 1031, 'humidity': 100, 'sea_level': 1031, 'grnd_level': 1025}, 'visibility': 2736, 'wind': {'speed': 1.74, 'deg': 149, 'gust': 1.74}, 'clouds': {'all': 100}, 'dt': 1643581812, 'sys': {'country': 'RU', 'sunrise': 1643590567, 'sunset': 1643612611}, 'timezone': 32400, 'id': 2012530, 'name': 'Zhigansk', 'cod': 200}
# Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=brae
# {'coord': {'lon': -1.353, 'lat': 60.3964}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 39.11, 'feels_like': 32.85, 'temp_min': 39.11, 'temp_max': 39.11, 'pressure': 1004, 'humidity': 97, 'sea_level': 1004, 'grnd_level': 1003}, 'visibility': 74, 'wind': {'speed': 9.33, 'deg': 156, 'gust': 14.12}, 'clouds': {'all': 100}, 'dt': 1643582039, 'sys': {'type': 1, 'id': 1438, 'country': 'GB', 'sunrise': 1643531196, 'sunset': 1643559036}, 'timezone': 0, 'id': 2654970, 'name': 'Brae', 'cod': 200}
# Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=thessalon
# {'coord': {'lon': -83.5666, 'lat': 46.2501}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 21.69, 'feels_like': 13.37, 'temp_min': 21.69, 'temp_max': 21.69, 'pressure': 1018, 'humidity': 93, 'sea_level': 1018, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 6.64, 'deg': 293, 'gust': 7.7}, 'clouds': {'all': 93}, 'dt': 1643582039, 'sys': {'type': 1, 'id': 3293, 'country': 'CA', 'sunrise': 1643547577, 'sunset': 1643582122}, 'timezone': -18000, 'id': 6164831, 'name': 'Thessalon', 'cod': 200}
# Thessalon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=anloga
# {'coord': {'lon': 0.8973, 'lat': 5.7947}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.42, 'feels_like': 75.96, 'temp_min': 75.42, 'temp_max': 75.42, 'pressure': 1010, 'humidity': 70, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 3.22, 'deg': 170, 'gust': 4.23}, 'clouds': {'all': 100}, 'dt': 1643582040, 'sys': {'type': 1, 'id': 1218, 'country': 'GH', 'sunrise': 1643523210, 'sunset': 1643565941}, 'timezone': 0, 'id': 2304548, 'name': 'Anloga', 'cod': 200}
# Anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=hualmay
# {'coord': {'lon': -77.6139, 'lat': -11.0964}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 72.19, 'feels_like': 72.82, 'temp_min': 72.19, 'temp_max': 72.19, 'pressure': 1013, 'humidity': 79, 'sea_level': 1013, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 9.84, 'deg': 177, 'gust': 12.21}, 'clouds': {'all': 100}, 'dt': 1643582040, 'sys': {'country': 'PE', 'sunrise': 1643540750, 'sunset': 1643586091}, 'timezone': -18000, 'id': 3939761, 'name': 'Hualmay', 'cod': 200}
# Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=kasiri
# {'coord': {'lon': -13.1148, 'lat': 8.9412}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 76.35, 'feels_like': 77.83, 'temp_min': 76.35, 'temp_max': 76.35, 'pressure': 1012, 'humidity': 88, 'sea_level': 1012, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 6.53, 'deg': 273, 'gust': 12.66}, 'clouds': {'all': 30}, 'dt': 1643582040, 'sys': {'country': 'SL', 'sunrise': 1643526816, 'sunset': 1643569062}, 'timezone': 0, 'id': 2406145, 'name': 'Kasiri', 'cod': 200}
# Kasiri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=cootamundra
# {'coord': {'lon': 148.0333, 'lat': -34.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 76.95, 'feels_like': 77.25, 'temp_min': 76.95, 'temp_max': 76.95, 'pressure': 1010, 'humidity': 62, 'sea_level': 1010, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 4.5, 'deg': 54, 'gust': 4.72}, 'clouds': {'all': 0}, 'dt': 1643582041, 'sys': {'type': 2, 'id': 2003667, 'country': 'AU', 'sunrise': 1643570786, 'sunset': 1643620552}, 'timezone': 39600, 'id': 2170430, 'name': 'Cootamundra', 'cod': 200}
# Cootamundra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=barrow
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': -7.58, 'feels_like': -20.18, 'temp_min': -7.58, 'temp_max': -7.58, 'pressure': 1029, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 270}, 'snow': {'1h': 2.29}, 'clouds': {'all': 100}, 'dt': 1643582041, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1643575810, 'sunset': 1643589040}, 'timezone': -32400, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 18.57, 'feels_like': 18.57, 'temp_min': 17.33, 'temp_max': 19.09, 'pressure': 1013, 'humidity': 44}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 100}, 'dt': 1643582042, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1643545916, 'sunset': 1643581703}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=torbay
# {'coord': {'lon': -52.7314, 'lat': 47.6666}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 38.21, 'feels_like': 25.65, 'temp_min': 37.27, 'temp_max': 38.75, 'pressure': 1004, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 32.21, 'deg': 250, 'gust': 46.04}, 'clouds': {'all': 75}, 'dt': 1643582042, 'sys': {'type': 1, 'id': 998, 'country': 'CA', 'sunrise': 1643540419, 'sunset': 1643574478}, 'timezone': -12600, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=birsk
# {'coord': {'lon': 55.5428, 'lat': 55.4211}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 21.81, 'feels_like': 13.64, 'temp_min': 21.81, 'temp_max': 21.81, 'pressure': 1009, 'humidity': 97, 'sea_level': 1009, 'grnd_level': 990}, 'visibility': 580, 'wind': {'speed': 6.51, 'deg': 133, 'gust': 16.69}, 'snow': {'1h': 0.15}, 'clouds': {'all': 100}, 'dt': 1643582042, 'sys': {'country': 'RU', 'sunrise': 1643602365, 'sunset': 1643633374}, 'timezone': 18000, 'id': 576317, 'name': 'Birsk', 'cod': 200}
# Birsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 77.05, 'feels_like': 77.18, 'temp_min': 75.4, 'temp_max': 78.12, 'pressure': 1018, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 360}, 'clouds': {'all': 40}, 'dt': 1643582012, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1643561757, 'sunset': 1643602277}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=jumla
# {'coord': {'lon': 82.1838, 'lat': 29.2747}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 35.2, 'feels_like': 31.77, 'temp_min': 35.2, 'temp_max': 35.2, 'pressure': 1013, 'humidity': 44, 'sea_level': 1013, 'grnd_level': 762}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 108, 'gust': 3.56}, 'clouds': {'all': 0}, 'dt': 1643582043, 'sys': {'country': 'NP', 'sunrise': 1643592069, 'sunset': 1643630881}, 'timezone': 20700, 'id': 1283285, 'name': 'Jumla', 'cod': 200}
# Jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': -7.85, 'feels_like': -20.45, 'temp_min': -8.88, 'temp_max': -6.59, 'pressure': 1017, 'humidity': 83}, 'visibility': 4828, 'wind': {'speed': 8.05, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1643581981, 'sys': {'type': 2, 'id': 2041581, 'country': 'CA', 'sunrise': 1643559059, 'sunset': 1643585419}, 'timezone': -25200, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=benjamin+constant
# {'coord': {'lon': -70.0311, 'lat': -4.3831}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.25, 'feels_like': 92.43, 'temp_min': 84.25, 'temp_max': 84.33, 'pressure': 1007, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 90}, 'clouds': {'all': 20}, 'dt': 1643582043, 'sys': {'type': 1, 'id': 8444, 'country': 'BR', 'sunrise': 1643539456, 'sunset': 1643583745}, 'timezone': -18000, 'id': 3665016, 'name': 'Benjamin Constant', 'cod': 200}
# Benjamin Constant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=leh
# {'coord': {'lon': 77.5833, 'lat': 34.1667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 9.37, 'feels_like': 9.37, 'temp_min': 9.37, 'temp_max': 9.37, 'pressure': 1024, 'humidity': 93, 'sea_level': 1024, 'grnd_level': 659}, 'visibility': 794, 'wind': {'speed': 2.19, 'deg': 141, 'gust': 2.59}, 'clouds': {'all': 100}, 'dt': 1643582043, 'sys': {'country': 'IN', 'sunrise': 1643593679, 'sunset': 1643631480}, 'timezone': 19800, 'id': 1264976, 'name': 'Leh', 'cod': 200}
# Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=three+hills
# {'coord': {'lon': -113.2686, 'lat': 51.7001}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 35.22, 'feels_like': 29.37, 'temp_min': 32.49, 'temp_max': 35.62, 'pressure': 1004, 'humidity': 47, 'sea_level': 1004, 'grnd_level': 899}, 'visibility': 10000, 'wind': {'speed': 7.02, 'deg': 159, 'gust': 11.45}, 'clouds': {'all': 60}, 'dt': 1643582044, 'sys': {'type': 2, 'id': 87038, 'country': 'CA', 'sunrise': 1643555691, 'sunset': 1643588267}, 'timezone': -25200, 'id': 6165875, 'name': 'Three Hills', 'cod': 200}
# Three Hills
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=bowen
# {'coord': {'lon': 148.2333, 'lat': -20.0167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.82, 'feels_like': 84.79, 'temp_min': 80.82, 'temp_max': 80.82, 'pressure': 1007, 'humidity': 73, 'sea_level': 1007, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 8.75, 'deg': 114, 'gust': 10.74}, 'clouds': {'all': 37}, 'dt': 1643582044, 'sys': {'type': 1, 'id': 9503, 'country': 'AU', 'sunrise': 1643572213, 'sunset': 1643619029}, 'timezone': 36000, 'id': 2174444, 'name': 'Bowen', 'cod': 200}
# Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=berlevag
# {'coord': {'lon': 29.0864, 'lat': 70.8578}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 28.35, 'feels_like': 21.16, 'temp_min': 28.2, 'temp_max': 30.2, 'pressure': 1000, 'humidity': 93}, 'visibility': 2000, 'wind': {'speed': 6.91, 'deg': 250}, 'snow': {'1h': 0.12}, 'clouds': {'all': 100}, 'dt': 1643582044, 'sys': {'type': 1, 'id': 1620, 'country': 'NO', 'sunrise': 1643530794, 'sunset': 1643544825}, 'timezone': 3600, 'id': 780687, 'name': 'Berlevåg', 'cod': 200}
# Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=tecoanapa
# {'coord': {'lon': -98.75, 'lat': 16.5167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 82.94, 'feels_like': 86.76, 'temp_min': 82.94, 'temp_max': 82.94, 'pressure': 1012, 'humidity': 64, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 8.7, 'deg': 237, 'gust': 10.18}, 'clouds': {'all': 3}, 'dt': 1643582045, 'sys': {'country': 'MX', 'sunrise': 1643547970, 'sunset': 1643589018}, 'timezone': -21600, 'id': 3516171, 'name': 'Barra de Tecoanapa', 'cod': 200}
# Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=wanning
# {'coord': {'lon': 110.3967, 'lat': 18.8003}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.33, 'feels_like': 69.96, 'temp_min': 69.33, 'temp_max': 69.33, 'pressure': 1015, 'humidity': 85, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 13.13, 'deg': 93, 'gust': 17.92}, 'clouds': {'all': 99}, 'dt': 1643582045, 'sys': {'country': 'CN', 'sunrise': 1643584358, 'sunset': 1643625048}, 'timezone': 28800, 'id': 1791779, 'name': 'Wanning', 'cod': 200}
# Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=luderitz
# {'coord': {'lon': 15.1594, 'lat': -26.6481}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.76, 'feels_like': 65.03, 'temp_min': 64.76, 'temp_max': 64.76, 'pressure': 1009, 'humidity': 87, 'sea_level': 1009, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 9.51, 'deg': 314, 'gust': 10.29}, 'clouds': {'all': 65}, 'dt': 1643581863, 'sys': {'country': 'NA', 'sunrise': 1643603553, 'sunset': 1643651572}, 'timezone': 7200, 'id': 3355672, 'name': 'Lüderitz', 'cod': 200}
# Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=avarua
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 71.65, 'feels_like': 73.22, 'temp_min': 71.65, 'temp_max': 71.65, 'pressure': 1014, 'humidity': 100}, 'visibility': 5000, 'wind': {'speed': 8.05, 'deg': 210}, 'clouds': {'all': 75}, 'dt': 1643582025, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1643559624, 'sunset': 1643606659}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=bambous+virieux
# {'coord': {'lon': 57.7575, 'lat': -20.3428}, 'weather': [{'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 79.05, 'feels_like': 79.05, 'temp_min': 78.22, 'temp_max': 79.05, 'pressure': 1009, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 160}, 'rain': {'1h': 0.37}, 'clouds': {'all': 75}, 'dt': 1643582045, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1643593908, 'sunset': 1643640768}, 'timezone': 14400, 'id': 1106677, 'name': 'Bambous Virieux', 'cod': 200}
# Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 26.11, 'feels_like': 14.56, 'temp_min': 26.11, 'temp_max': 26.11, 'pressure': 1015, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 300, 'gust': 21.85}, 'clouds': {'all': 0}, 'dt': 1643582046, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1643566558, 'sunset': 1643596188}, 'timezone': -32400, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=estevan
# {'coord': {'lon': -102.9842, 'lat': 49.1334}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 26.76, 'feels_like': 19.42, 'temp_min': 25.21, 'temp_max': 28.74, 'pressure': 1007, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 269, 'gust': 12.84}, 'clouds': {'all': 0}, 'dt': 1643582046, 'sys': {'type': 1, 'id': 790, 'country': 'CA', 'sunrise': 1643552728, 'sunset': 1643586293}, 'timezone': -21600, 'id': 5949568, 'name': 'Estevan', 'cod': 200}
# Estevan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=isla+mujeres
# {'coord': {'lon': -86.731, 'lat': 21.2311}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 71.17, 'feels_like': 70.9, 'temp_min': 71.17, 'temp_max': 71.65, 'pressure': 1021, 'humidity': 62, 'sea_level': 1021, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 9.69, 'deg': 46, 'gust': 10.47}, 'clouds': {'all': 89}, 'dt': 1643582047, 'sys': {'type': 2, 'id': 47730, 'country': 'MX', 'sunrise': 1643545483, 'sunset': 1643585735}, 'timezone': -18000, 'id': 3526756, 'name': 'Isla Mujeres', 'cod': 200}
# Isla Mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=tuktoyaktuk
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': -0.4, 'feels_like': -13, 'temp_min': -0.4, 'temp_max': -0.4, 'pressure': 1021, 'humidity': 85}, 'visibility': 805, 'wind': {'speed': 24.16, 'deg': 300}, 'clouds': {'all': 100}, 'dt': 1643582047, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1643567909, 'sunset': 1643585539}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=aiquile
# {'coord': {'lon': -65.1807, 'lat': -18.2041}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 62.51, 'feels_like': 61.79, 'temp_min': 62.51, 'temp_max': 62.51, 'pressure': 1007, 'humidity': 71, 'sea_level': 1007, 'grnd_level': 778}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 78, 'gust': 10.51}, 'clouds': {'all': 23}, 'dt': 1643582048, 'sys': {'country': 'BO', 'sunrise': 1643537176, 'sunset': 1643583697}, 'timezone': -14400, 'id': 3924341, 'name': 'Aiquile', 'cod': 200}
# Aiquile
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=faanui
# {'coord': {'lon': -151.75, 'lat': -16.4833}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 80.83, 'feels_like': 84.67, 'temp_min': 80.83, 'temp_max': 80.83, 'pressure': 1013, 'humidity': 72, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 10.51, 'deg': 61, 'gust': 10.98}, 'clouds': {'all': 15}, 'dt': 1643582048, 'sys': {'country': 'PF', 'sunrise': 1643558107, 'sunset': 1643604324}, 'timezone': -36000, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.86, 'feels_like': 77.54, 'temp_min': 76.86, 'temp_max': 76.86, 'pressure': 1016, 'humidity': 70, 'sea_level': 1016, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 5.06, 'deg': 162, 'gust': 6.02}, 'clouds': {'all': 100}, 'dt': 1643582030, 'sys': {'country': 'PF', 'sunrise': 1643553494, 'sunset': 1643600882}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=nangomba
# ...
# Jiaozuo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=lerwick
# {'coord': {'lon': -1.1494, 'lat': 60.1545}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 39.2, 'feels_like': 32.59, 'temp_min': 39.2, 'temp_max': 39.2, 'pressure': 1004, 'humidity': 97, 'sea_level': 1004, 'grnd_level': 1004}, 'visibility': 69, 'wind': {'speed': 10.13, 'deg': 146, 'gust': 13.47}, 'clouds': {'all': 100}, 'dt': 1643582220, 'sys': {'type': 1, 'id': 1438, 'country': 'GB', 'sunrise': 1643531062, 'sunset': 1643559072}, 'timezone': 0, 'id': 2644605, 'name': 'Lerwick', 'cod': 200}
# Lerwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=hinganghat
# {'coord': {'lon': 78.8333, 'lat': 20.5667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 54.81, 'feels_like': 51.26, 'temp_min': 54.81, 'temp_max': 54.81, 'pressure': 1011, 'humidity': 27, 'sea_level': 1011, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 3.8, 'deg': 344, 'gust': 3.83}, 'clouds': {'all': 0}, 'dt': 1643582220, 'sys': {'type': 1, 'id': 9069, 'country': 'IN', 'sunrise': 1643592081, 'sunset': 1643632477}, 'timezone': 19800, 'id': 1270077, 'name': 'Hinganghāt', 'cod': 200}
# Hinganghat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=hemnesberget
# {'coord': {'lon': 13.6333, 'lat': 66.2333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 22.51, 'feels_like': 22.51, 'temp_min': 21.7, 'temp_max': 30.67, 'pressure': 1010, 'humidity': 99, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 1.97, 'deg': 130, 'gust': 1.86}, 'clouds': {'all': 52}, 'dt': 1643582221, 'sys': {'type': 1, 'id': 1651, 'country': 'NO', 'sunrise': 1643530317, 'sunset': 1643552720}, 'timezone': 3600, 'id': 3152995, 'name': 'Hemnesberget', 'cod': 200}
# Hemnesberget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=butka
# {'coord': {'lon': 63.7866, 'lat': 56.7179}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 8.37, 'feels_like': 1.06, 'temp_min': 8.37, 'temp_max': 8.37, 'pressure': 1015, 'humidity': 95, 'sea_level': 1015, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 3.83, 'deg': 247, 'gust': 6.67}, 'clouds': {'all': 100}, 'dt': 1643582221, 'sys': {'country': 'RU', 'sunrise': 1643600725, 'sunset': 1643631057}, 'timezone': 18000, 'id': 1508589, 'name': 'Butka', 'cod': 200}
# Butka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=erhlin
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=solsvik
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=rio+gallegos
# {'coord': {'lon': -69.2181, 'lat': -51.6226}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 57.25, 'feels_like': 54, 'temp_min': 57.25, 'temp_max': 57.25, 'pressure': 1004, 'humidity': 28}, 'visibility': 10000, 'wind': {'speed': 31.07, 'deg': 230, 'gust': 42.57}, 'clouds': {'all': 20}, 'dt': 1643582221, 'sys': {'type': 1, 'id': 8293, 'country': 'AR', 'sunrise': 1643533762, 'sunset': 1643589049}, 'timezone': -10800, 'id': 3838859, 'name': 'Río Gallegos', 'cod': 200}
# Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=obihiro
# {'coord': {'lon': 143.2044, 'lat': 42.9172}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 0.64, 'feels_like': 0.64, 'temp_min': 0.64, 'temp_max': 0.64, 'pressure': 1012, 'humidity': 92, 'sea_level': 1012, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 2.26, 'deg': 324, 'gust': 2.8}, 'clouds': {'all': 23}, 'dt': 1643582222, 'sys': {'country': 'JP', 'sunrise': 1643579024, 'sunset': 1643614633}, 'timezone': 32400, 'id': 2128815, 'name': 'Obihiro', 'cod': 200}
# Obihiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=ust-nera
# {'coord': {'lon': 143.2, 'lat': 64.5667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -9.18, 'feels_like': -9.18, 'temp_min': -9.18, 'temp_max': -9.18, 'pressure': 1028, 'humidity': 99, 'sea_level': 1028, 'grnd_level': 962}, 'visibility': 5996, 'wind': {'speed': 1.79, 'deg': 309, 'gust': 1.95}, 'clouds': {'all': 100}, 'dt': 1643582222, 'sys': {'country': 'RU', 'sunrise': 1643584563, 'sunset': 1643609095}, 'timezone': 36000, 'id': 2120048, 'name': 'Ust-Nera', 'cod': 200}
# Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=necochea
# {'coord': {'lon': -58.7368, 'lat': -38.5473}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 67.03, 'feels_like': 66.4, 'temp_min': 67.03, 'temp_max': 67.03, 'pressure': 1006, 'humidity': 63, 'sea_level': 1006, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 22.32, 'deg': 193, 'gust': 25.7}, 'clouds': {'all': 77}, 'dt': 1643581971, 'sys': {'type': 2, 'id': 2010353, 'country': 'AR', 'sunrise': 1643533493, 'sunset': 1643584286}, 'timezone': -10800, 'id': 3430443, 'name': 'Necochea', 'cod': 200}
# Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=kilosa
# {'coord': {'lon': 36.9833, 'lat': -6.8333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 70.63, 'feels_like': 72.05, 'temp_min': 70.63, 'temp_max': 70.63, 'pressure': 1011, 'humidity': 99, 'sea_level': 1011, 'grnd_level': 955}, 'visibility': 7966, 'wind': {'speed': 2.3, 'deg': 44, 'gust': 8.28}, 'rain': {'1h': 0.77}, 'clouds': {'all': 100}, 'dt': 1643582222, 'sys': {'country': 'TZ', 'sunrise': 1643599996, 'sunset': 1643644652}, 'timezone': 10800, 'id': 157403, 'name': 'Kilosa', 'cod': 200}
# Kilosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=luanda
# {'coord': {'lon': 13.2343, 'lat': -8.8368}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 78.8, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1011, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 150}, 'clouds': {'all': 75}, 'dt': 1643582021, 'sys': {'type': 1, 'id': 2173, 'country': 'AO', 'sunrise': 1643519121, 'sunset': 1643564108}, 'timezone': 3600, 'id': 2240449, 'name': 'Luanda', 'cod': 200}
# Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=arys
# {'coord': {'lon': 68.795, 'lat': 42.4252}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 26.82, 'feels_like': 20.17, 'temp_min': 26.82, 'temp_max': 26.82, 'pressure': 1025, 'humidity': 72, 'sea_level': 1025, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 5.86, 'deg': 12, 'gust': 7.85}, 'clouds': {'all': 10}, 'dt': 1643582223, 'sys': {'type': 1, 'id': 8824, 'country': 'KZ', 'sunrise': 1643596800, 'sunset': 1643632577}, 'timezone': 21600, 'id': 1526168, 'name': 'Arys', 'cod': 200}
# Arys
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=mantua
# {'coord': {'lon': 10.7833, 'lat': 45.1667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 36.23, 'feels_like': 36.23, 'temp_min': 34.99, 'temp_max': 43.48, 'pressure': 1019, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 41, 'gust': 3}, 'clouds': {'all': 0}, 'dt': 1643582223, 'sys': {'type': 2, 'id': 2011529, 'country': 'IT', 'sunrise': 1643524779, 'sunset': 1643559627}, 'timezone': 3600, 'id': 3174050, 'name': 'Province of Mantua', 'cod': 200}
# Mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=makakilo+city
# {'coord': {'lon': -158.0858, 'lat': 21.3469}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 77.79, 'feels_like': 77.86, 'temp_min': 75.61, 'temp_max': 79.12, 'pressure': 1018, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 120}, 'clouds': {'all': 0}, 'dt': 1643582223, 'sys': {'type': 1, 'id': 7868, 'country': 'US', 'sunrise': 1643562614, 'sunset': 1643602858}, 'timezone': -36000, 'id': 5850554, 'name': 'Makakilo City', 'cod': 200}
# Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=tarudant
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=ayagoz
# {'coord': {'lon': 80.4392, 'lat': 47.9714}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 7.95, 'feels_like': 7.95, 'temp_min': 7.95, 'temp_max': 7.95, 'pressure': 1032, 'humidity': 100, 'sea_level': 1032, 'grnd_level': 946}, 'visibility': 4062, 'wind': {'speed': 2.42, 'deg': 219, 'gust': 2.51}, 'clouds': {'all': 99}, 'dt': 1643582224, 'sys': {'country': 'KZ', 'sunrise': 1643594863, 'sunset': 1643628924}, 'timezone': 21600, 'id': 1525988, 'name': 'Ayagoz', 'cod': 200}
# Ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=the+valley
# {'coord': {'lon': -63.0578, 'lat': 18.217}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 78.89, 'feels_like': 78.89, 'temp_min': 77.83, 'temp_max': 78.94, 'pressure': 1015, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 90}, 'clouds': {'all': 20}, 'dt': 1643582224, 'sys': {'type': 1, 'id': 8788, 'country': 'AI', 'sunrise': 1643539546, 'sunset': 1643580308}, 'timezone': -14400, 'id': 3573374, 'name': 'The Valley', 'cod': 200}
# The Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=tierra+blanca
# {'coord': {'lon': -88.5833, 'lat': 14.5833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 62.94, 'feels_like': 63.16, 'temp_min': 62.26, 'temp_max': 69.82, 'pressure': 1020, 'humidity': 90, 'sea_level': 1020, 'grnd_level': 927}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 10, 'gust': 7.83}, 'clouds': {'all': 99}, 'dt': 1643582224, 'sys': {'type': 1, 'id': 7090, 'country': 'HN', 'sunrise': 1643545373, 'sunset': 1643586734}, 'timezone': -21600, 'id': 3600800, 'name': 'Tierra Blanca', 'cod': 200}
# Tierra Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=stykkisholmur
# {'coord': {'lon': -22.7297, 'lat': 65.0757}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.75, 'feels_like': 12.15, 'temp_min': 24.75, 'temp_max': 24.75, 'pressure': 1008, 'humidity': 54, 'sea_level': 1008, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 27.16, 'deg': 276, 'gust': 35.63}, 'clouds': {'all': 100}, 'dt': 1643582224, 'sys': {'country': 'IS', 'sunrise': 1643538354, 'sunset': 1643562139}, 'timezone': 0, 'id': 3412888, 'name': 'Stykkisholmur', 'cod': 200}
# Stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=yurla
# {'coord': {'lon': 54.3223, 'lat': 59.3259}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -3.37, 'feels_like': -3.37, 'temp_min': -3.37, 'temp_max': -3.37, 'pressure': 1013, 'humidity': 100, 'sea_level': 1013, 'grnd_level': 990}, 'visibility': 4848, 'wind': {'speed': 2.39, 'deg': 127, 'gust': 2.28}, 'clouds': {'all': 96}, 'dt': 1643582225, 'sys': {'country': 'RU', 'sunrise': 1643603758, 'sunset': 1643632567}, 'timezone': 18000, 'id': 466349, 'name': 'Yurla', 'cod': 200}
# Yurla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=leninskoye
# {'coord': {'lon': 69.3864, 'lat': 41.7589}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 31.93, 'feels_like': 28.42, 'temp_min': 22.78, 'temp_max': 31.93, 'pressure': 1023, 'humidity': 58, 'sea_level': 1023, 'grnd_level': 952}, 'visibility': 10000, 'wind': {'speed': 3.62, 'deg': 44, 'gust': 3.67}, 'clouds': {'all': 28}, 'dt': 1643582225, 'sys': {'type': 1, 'id': 9016, 'country': 'KZ', 'sunrise': 1643596567, 'sunset': 1643632526}, 'timezone': 21600, 'id': 1521351, 'name': 'Kazygurt', 'cod': 200}
# Leninskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=kadykchan
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=saint+pete+beach
# {'coord': {'lon': -82.7412, 'lat': 27.7253}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 51.89, 'feels_like': 48.52, 'temp_min': 48, 'temp_max': 55.4, 'pressure': 1024, 'humidity': 37}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 212, 'gust': 8.99}, 'clouds': {'all': 0}, 'dt': 1643582226, 'sys': {'type': 2, 'id': 2008087, 'country': 'US', 'sunrise': 1643545117, 'sunset': 1643584186}, 'timezone': -18000, 'id': 4171522, 'name': 'St. Pete Beach', 'cod': 200}
# Saint Pete Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=karibib
# {'coord': {'lon': 15.8333, 'lat': -21.9333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 66.09, 'feels_like': 65.79, 'temp_min': 66.09, 'temp_max': 66.09, 'pressure': 1011, 'humidity': 72, 'sea_level': 1011, 'grnd_level': 885}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 226, 'gust': 8.37}, 'rain': {'1h': 0.29}, 'clouds': {'all': 100}, 'dt': 1643582226, 'sys': {'country': 'NA', 'sunrise': 1643603833, 'sunset': 1643650969}, 'timezone': 7200, 'id': 3356332, 'name': 'Karibib', 'cod': 200}
# Karibib
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350dca8daa6e9af9c96e19c04acaff6a&q=buala
# {'coord': {'lon': 159.5921, 'lat': -8.145}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 83.84, 'feels_like': 91.44, 'temp_min': 83.84, 'temp_max': 83.84, 'pressure': 1009, 'humidity': 74, 'sea_level': 1009, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 5.06, 'deg': 358, 'gust': 6.53}, 'rain': {'1h': 0.32}, 'clouds': {'all': 99}, 'dt': 1643582226, 'sys': {'country': 'SB', 'sunrise': 1643570462, 'sunset': 1643615328}, 'timezone': 39600, 'id': 2109528, 'name': 'Buala', 'cod': 200}
# Buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 67.33,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 79.88,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 13.13,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 79.09,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 11.14,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 47.86,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 28.77,
#   'Weather Description': 'light intensity drizzle'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 81.77,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 10.22,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 71.65,
#   'Humidity': 65,
#   'Cloudiness': 95,
#   'Wind Speed': 12.35,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 79.81,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 12.06,
#   'Weather Description': 'light rain'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 78.3,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 47.86,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 28.77,
#   'Weather Description': 'light intensity drizzle'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 80.26,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 10.11,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 62.13,
#   'Humidity': 56,
#   'Cloudiness': 27,
#   'Wind Speed': 12.57,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Machala',
#   'Lat': -3.2667,
#   'Lng': -79.9667,
#   'Max Temp': 84.15,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Weather Description': 'light rain'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 70.92,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 8.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 27.39,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Weather Description': 'light snow'},
#  {'City': 'Roxas',
#   'Lat': 11.5853,
#   'Lng': 122.7511,
#   'Max Temp': 76.57,
#   'Humidity': 86,
#   'Cloudiness': 84,
#   'Wind Speed': 1.59,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 82.36,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 68.88,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': -10.1,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 59.11,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 64.9,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 6.51,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 53.71,
#   'Humidity': 40,
#   'Cloudiness': 40,
#   'Wind Speed': 28.77,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 59.76,
#   'Humidity': 78,
#   'Cloudiness': 5,
#   'Wind Speed': 1.97,
#   'Weather Description': 'clear sky'},
#  {'City': 'Wabag',
#   'Lat': -5.4781,
#   'Lng': 143.7021,
#   'Max Temp': 54.16,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 2.93,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': -11.07,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Begoro',
#   'Lat': 6.3871,
#   'Lng': -0.3774,
#   'Max Temp': 74.25,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Guadalupe Y Calvo',
#   'Lat': 26.1,
#   'Lng': -106.9667,
#   'Max Temp': 57.27,
#   'Humidity': 28,
#   'Cloudiness': 31,
#   'Wind Speed': 13.33,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 8.76,
#   'Humidity': 45,
#   'Cloudiness': 95,
#   'Wind Speed': 17.18,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 79.36,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Weather Description': 'light rain'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 63.48,
#   'Humidity': 82,
#   'Cloudiness': 47,
#   'Wind Speed': 1.19,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kisanga',
#   'Lat': -7.4362,
#   'Lng': 37.7034,
#   'Max Temp': 73.74,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 4.27,
#   'Weather Description': 'light rain'},
#  {'City': 'Mahibadhoo',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 82,
#   'Humidity': 75,
#   'Cloudiness': 84,
#   'Wind Speed': 11.54,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 67.93,
#   'Humidity': 80,
#   'Cloudiness': 17,
#   'Wind Speed': 2.26,
#   'Weather Description': 'few clouds'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 39.29,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Izazi',
#   'Lat': -7.2,
#   'Lng': 35.7333,
#   'Max Temp': 71.2,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Weather Description': 'light rain'},
#  {'City': 'Matara',
#   'Lat': 5.9485,
#   'Lng': 80.5353,
#   'Max Temp': 75.6,
#   'Humidity': 93,
#   'Cloudiness': 36,
#   'Wind Speed': 7.36,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 69.84,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Weather Description': 'mist'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 64.24,
#   'Humidity': 71,
#   'Cloudiness': 48,
#   'Wind Speed': 8.99,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.81,
#   'Humidity': 76,
#   'Cloudiness': 18,
#   'Wind Speed': 21.03,
#   'Weather Description': 'light rain'},
#  {'City': 'Ginir',
#   'Lat': 7.1333,
#   'Lng': 40.7,
#   'Max Temp': 58.69,
#   'Humidity': 19,
#   'Cloudiness': 77,
#   'Wind Speed': 6.29,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.61,
#   'Humidity': 70,
#   'Cloudiness': 81,
#   'Wind Speed': 9.04,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -12.53,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 2.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nara',
#   'Lat': 34.6851,
#   'Lng': 135.8049,
#   'Max Temp': 34.97,
#   'Humidity': 71,
#   'Cloudiness': 32,
#   'Wind Speed': 2.17,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 70.81,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.65,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': -33.83,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 39.11,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Thessalon',
#   'Lat': 46.2501,
#   'Lng': -83.5666,
#   'Max Temp': 25.29,
#   'Humidity': 81,
#   'Cloudiness': 92,
#   'Wind Speed': 5.44,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 82.62,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 73.08,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 9.71,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kasiri',
#   'Lat': 8.9412,
#   'Lng': -13.1148,
#   'Max Temp': 82.58,
#   'Humidity': 84,
#   'Cloudiness': 47,
#   'Wind Speed': 7.85,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cootamundra',
#   'Lat': -34.65,
#   'Lng': 148.0333,
#   'Max Temp': 67.95,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -9.38,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 21.02,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 43.57,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 33.38,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Birsk',
#   'Lat': 55.4211,
#   'Lng': 55.5428,
#   'Max Temp': 20.66,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 6.73,
#   'Weather Description': 'light snow'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 78.53,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Weather Description': 'few clouds'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 35.82,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 4.21,
#   'Weather Description': 'clear sky'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -7.58,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Weather Description': 'mist'},
#  {'City': 'Benjamin Constant',
#   'Lat': -4.3831,
#   'Lng': -70.0311,
#   'Max Temp': 89.73,
#   'Humidity': 48,
#   'Cloudiness': 92,
#   'Wind Speed': 3.02,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Leh',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 6.08,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Three Hills',
#   'Lat': 51.7001,
#   'Lng': -113.2686,
#   'Max Temp': 45.48,
#   'Humidity': 42,
#   'Cloudiness': 50,
#   'Wind Speed': 8.43,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 75.42,
#   'Humidity': 83,
#   'Cloudiness': 55,
#   'Wind Speed': 7.58,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 30.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Weather Description': 'light snow'},
#  {'City': 'Tecoanapa',
#   'Lat': 16.5167,
#   'Lng': -98.75,
#   'Max Temp': 83.98,
#   'Humidity': 62,
#   'Cloudiness': 3,
#   'Wind Speed': 10.96,
#   'Weather Description': 'clear sky'},
#  {'City': 'Wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 69.3,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 14.67,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 66.11,
#   'Humidity': 85,
#   'Cloudiness': 89,
#   'Wind Speed': 8.28,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.25,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79.21,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Weather Description': 'light rain'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 26.11,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Estevan',
#   'Lat': 49.1334,
#   'Lng': -102.9842,
#   'Max Temp': 30.54,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 9.35,
#   'Weather Description': 'clear sky'},
#  {'City': 'Isla Mujeres',
#   'Lat': 21.2311,
#   'Lng': -86.731,
#   'Max Temp': 73.45,
#   'Humidity': 60,
#   'Cloudiness': 81,
#   'Wind Speed': 10.31,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -2.2,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Weather Description': 'light snow'},
#  {'City': 'Aiquile',
#   'Lat': -18.2041,
#   'Lng': -65.1807,
#   'Max Temp': 72.9,
#   'Humidity': 39,
#   'Cloudiness': 24,
#   'Wind Speed': 13.2,
#   'Weather Description': 'few clouds'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.2,
#   'Humidity': 73,
#   'Cloudiness': 11,
#   'Wind Speed': 7.52,
#   'Weather Description': 'light rain'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 76.33,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nangomba',
#   'Lat': -10.9,
#   'Lng': 38.5,
#   'Max Temp': 71.08,
#   'Humidity': 94,
#   'Cloudiness': 89,
#   'Wind Speed': 1.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 27.55,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Weather Description': 'snow'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 74.1,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 18.9,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pierre',
#   'Lat': 44.3683,
#   'Lng': -100.351,
#   'Max Temp': 46.27,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Antalaha',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 75.65,
#   'Humidity': 87,
#   'Cloudiness': 14,
#   'Wind Speed': 7.96,
#   'Weather Description': 'few clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.39,
#   'Humidity': 81,
#   'Cloudiness': 48,
#   'Wind Speed': 12.24,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 77.47,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Manado',
#   'Lat': 1.487,
#   'Lng': 124.8455,
#   'Max Temp': 74.17,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 1.14,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Glenwood Springs',
#   'Lat': 39.5505,
#   'Lng': -107.3248,
#   'Max Temp': 49.23,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 81.9,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Weather Description': 'few clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 74.34,
#   'Humidity': 85,
#   'Cloudiness': 77,
#   'Wind Speed': 14.32,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 70.95,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Weather Description': 'light rain'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 21.74,
#   'Humidity': 38,
#   'Cloudiness': 13,
#   'Wind Speed': 1.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -6.81,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 9.93,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -7.91,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 73.02,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Weather Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 36.52,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 34.96,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Erdenet',
#   'Lat': 49.0333,
#   'Lng': 104.0833,
#   'Max Temp': -11.56,
#   'Humidity': 94,
#   'Cloudiness': 10,
#   'Wind Speed': 3.76,
#   'Weather Description': 'clear sky'},
#  {'City': 'Qom',
#   'Lat': 34.6401,
#   'Lng': 50.8764,
#   'Max Temp': 41.92,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 78.84,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 81.09,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 10.42,
#   'Weather Description': 'light rain'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 79.9,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Weather Description': 'few clouds'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 51.4,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 4.65,
#   'Weather Description': 'clear sky'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 63.09,
#   'Humidity': 65,
#   'Cloudiness': 87,
#   'Wind Speed': 17.78,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tambacounda',
#   'Lat': 13.7539,
#   'Lng': -13.7586,
#   'Max Temp': 91.45,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Weather Description': 'clear sky'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 65.88,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Weather Description': 'few clouds'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 44.51,
#   'Humidity': 53,
#   'Cloudiness': 15,
#   'Wind Speed': 7.25,
#   'Weather Description': 'few clouds'},
#  {'City': 'Dali',
#   'Lat': 25.7,
#   'Lng': 100.1833,
#   'Max Temp': 37.11,
#   'Humidity': 87,
#   'Cloudiness': 26,
#   'Wind Speed': 3,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 77.38,
#   'Humidity': 80,
#   'Cloudiness': 27,
#   'Wind Speed': 13.22,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 0.99,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Weather Description': 'light snow'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 72.72,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 9.31,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 74.1,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Weather Description': 'few clouds'},
#  {'City': 'Peno',
#   'Lat': 56.9262,
#   'Lng': 32.7426,
#   'Max Temp': 23.45,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.35,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 76.44,
#   'Humidity': 63,
#   'Cloudiness': 26,
#   'Wind Speed': 13.98,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -2.78,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 20.98,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -2.63,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 9.42,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 66.25,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 9.57,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 81.21,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Caceres',
#   'Lat': 39.522,
#   'Lng': -6.3748,
#   'Max Temp': 46.8,
#   'Humidity': 51,
#   'Cloudiness': 46,
#   'Wind Speed': 2.17,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint-Denis',
#   'Lat': 48.9167,
#   'Lng': 2.3333,
#   'Max Temp': 46.15,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 28.15,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 75.09,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Weather Description': 'shower rain'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 82.36,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 5,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Weather Description': 'light snow'},
#  {'City': 'Honningsvag',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 31.75,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Weather Description': 'few clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -29.16,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 82.36,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Punta Alta',
#   'Lat': -38.8759,
#   'Lng': -62.0736,
#   'Max Temp': 65.07,
#   'Humidity': 56,
#   'Cloudiness': 58,
#   'Wind Speed': 23.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Jiazi',
#   'Lat': 22.8779,
#   'Lng': 116.067,
#   'Max Temp': 55.67,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 18.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': -6.9,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 65.12,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 9.15,
#   'Weather Description': 'clear sky'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -12.42,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Jeronimo',
#   'Lat': -11.9472,
#   'Lng': -75.2829,
#   'Max Temp': 50.58,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 43.03,
#   'Humidity': 42,
#   'Cloudiness': 6,
#   'Wind Speed': 8.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 27.3,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 29.19,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 60.55,
#   'Humidity': 80,
#   'Cloudiness': 7,
#   'Wind Speed': 7,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 62.51,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Conceicao Do Araguaia',
#   'Lat': -8.2578,
#   'Lng': -49.2647,
#   'Max Temp': 76.69,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Moreira Sales',
#   'Lat': -24.0622,
#   'Lng': -53.0069,
#   'Max Temp': 80.06,
#   'Humidity': 72,
#   'Cloudiness': 29,
#   'Wind Speed': 3.87,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 26.11,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 23.24,
#   'Weather Description': 'clear sky'},
#  {'City': 'Abu Kamal',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 47.12,
#   'Humidity': 59,
#   'Cloudiness': 44,
#   'Wind Speed': 9.4,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 6.82,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ambanja',
#   'Lat': -13.6833,
#   'Lng': 48.45,
#   'Max Temp': 76.03,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 2.91,
#   'Weather Description': 'light rain'},
#  {'City': 'Debre Sina',
#   'Lat': 9.85,
#   'Lng': 39.7667,
#   'Max Temp': 48.29,
#   'Humidity': 54,
#   'Cloudiness': 5,
#   'Wind Speed': 1.52,
#   'Weather Description': 'clear sky'},
#  {'City': 'Elko',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': 42.06,
#   'Humidity': 48,
#   'Cloudiness': 6,
#   'Wind Speed': 4,
#   'Weather Description': 'clear sky'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 74.5,
#   'Humidity': 93,
#   'Cloudiness': 82,
#   'Wind Speed': 3.42,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yinchuan',
#   'Lat': 38.4681,
#   'Lng': 106.2731,
#   'Max Temp': 16.7,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 6.51,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ilhabela',
#   'Lat': -23.7781,
#   'Lng': -45.3581,
#   'Max Temp': 74.93,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 21.42,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 12.91,
#   'Weather Description': 'light snow'},
#  {'City': 'Lixourion',
#   'Lat': 38.2019,
#   'Lng': 20.4314,
#   'Max Temp': 51.42,
#   'Humidity': 65,
#   'Cloudiness': 3,
#   'Wind Speed': 15.39,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sri Aman',
#   'Lat': 1.2376,
#   'Lng': 111.4621,
#   'Max Temp': 77.09,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Parksville',
#   'Lat': 49.3163,
#   'Lng': -124.3195,
#   'Max Temp': 45.64,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Weather Description': 'light rain'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 71.78,
#   'Humidity': 57,
#   'Cloudiness': 95,
#   'Wind Speed': 4.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zhanaozen',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 38.88,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 12.88,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 82.42,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 20,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 63.64,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': -17.57,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 73.36,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 74.97,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 17.45,
#   'Weather Description': 'clear sky'},
#  {'City': 'Haimen',
#   'Lat': 23.1935,
#   'Lng': 116.6142,
#   'Max Temp': 51.69,
#   'Humidity': 73,
#   'Cloudiness': 92,
#   'Wind Speed': 17.6,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hartselle',
#   'Lat': 34.4434,
#   'Lng': -86.9353,
#   'Max Temp': 59.86,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 10.31,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 77.99,
#   'Humidity': 83,
#   'Cloudiness': 23,
#   'Wind Speed': 0.49,
#   'Weather Description': 'few clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 85.1,
#   'Humidity': 74,
#   'Cloudiness': 21,
#   'Wind Speed': 12.84,
#   'Weather Description': 'few clouds'},
#  {'City': 'Masakin',
#   'Lat': 35.7292,
#   'Lng': 10.5808,
#   'Max Temp': 55.6,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 3.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 78.94,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Weather Description': 'light rain'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 71.89,
#   'Humidity': 95,
#   'Cloudiness': 74,
#   'Wind Speed': 6.11,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 63.75,
#   'Humidity': 76,
#   'Cloudiness': 21,
#   'Wind Speed': 0.04,
#   'Weather Description': 'few clouds'},
#  {'City': 'Anaco',
#   'Lat': 9.4389,
#   'Lng': -64.4728,
#   'Max Temp': 85.57,
#   'Humidity': 40,
#   'Cloudiness': 93,
#   'Wind Speed': 6.42,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 31.42,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Weather Description': 'mist'},
#  {'City': 'Calabozo',
#   'Lat': 8.9242,
#   'Lng': -67.4293,
#   'Max Temp': 94.66,
#   'Humidity': 19,
#   'Cloudiness': 23,
#   'Wind Speed': 8.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Starkville',
#   'Lat': 33.4504,
#   'Lng': -88.8184,
#   'Max Temp': 62.26,
#   'Humidity': 42,
#   'Cloudiness': 5,
#   'Wind Speed': 9.51,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bikin',
#   'Lat': 46.8161,
#   'Lng': 134.26,
#   'Max Temp': -21.33,
#   'Humidity': 100,
#   'Cloudiness': 46,
#   'Wind Speed': 1.88,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 37.29,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Baherden',
#   'Lat': 38.4362,
#   'Lng': 57.4316,
#   'Max Temp': 43.02,
#   'Humidity': 52,
#   'Cloudiness': 2,
#   'Wind Speed': 7.09,
#   'Weather Description': 'clear sky'},
#  {'City': 'Seymchan',
#   'Lat': 62.8833,
#   'Lng': 152.4333,
#   'Max Temp': -22.02,
#   'Humidity': 96,
#   'Cloudiness': 87,
#   'Wind Speed': 4.09,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Varhaug',
#   'Lat': 58.6147,
#   'Lng': 5.6457,
#   'Max Temp': 36.48,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 5.12,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 26.01,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 79.25,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 66.18,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Aleksandrovskiy Zavod',
#   'Lat': 50.9237,
#   'Lng': 117.9374,
#   'Max Temp': -18.45,
#   'Humidity': 97,
#   'Cloudiness': 47,
#   'Wind Speed': 3.36,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Dukat',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': -14.62,
#   'Humidity': 99,
#   'Cloudiness': 93,
#   'Wind Speed': 5.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rafaela',
#   'Lat': -31.2503,
#   'Lng': -61.4867,
#   'Max Temp': 91.98,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 64.15,
#   'Humidity': 93,
#   'Cloudiness': 42,
#   'Wind Speed': 5.84,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.97,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Biltine',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp': 66.06,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 10.65,
#   'Weather Description': 'clear sky'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -17.91,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 31.55,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 39.03,
#   'Weather Description': 'light snow'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 65.8,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 10,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ljungby',
#   'Lat': 56.8332,
#   'Lng': 13.9408,
#   'Max Temp': 32.79,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 12.46,
#   'Weather Description': 'clear sky'},
#  {'City': 'Chato',
#   'Lat': -2.6378,
#   'Lng': 31.7669,
#   'Max Temp': 68.63,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.05,
#   'Weather Description': 'light rain'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.01,
#   'Humidity': 77,
#   'Cloudiness': 9,
#   'Wind Speed': 13.47,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mangan',
#   'Lat': 27.5167,
#   'Lng': 88.5333,
#   'Max Temp': 50.07,
#   'Humidity': 66,
#   'Cloudiness': 89,
#   'Wind Speed': 4.21,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lafiagi',
#   'Lat': 8.8667,
#   'Lng': 5.4167,
#   'Max Temp': 80.6,
#   'Humidity': 11,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mao',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 50.56,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tobias Barreto',
#   'Lat': -11.1839,
#   'Lng': -37.9983,
#   'Max Temp': 80.17,
#   'Humidity': 65,
#   'Cloudiness': 45,
#   'Wind Speed': 15.86,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 73.24,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -19.97,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mecca',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 69.39,
#   'Humidity': 56,
#   'Cloudiness': 98,
#   'Wind Speed': 3.96,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Puerto Gaitan',
#   'Lat': 4.3133,
#   'Lng': -72.0816,
#   'Max Temp': 94.37,
#   'Humidity': 27,
#   'Cloudiness': 84,
#   'Wind Speed': 15.35,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 70.77,
#   'Humidity': 80,
#   'Cloudiness': 7,
#   'Wind Speed': 1.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 17.19,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 16.33,
#   'Weather Description': 'light snow'},
#  {'City': 'Vitre',
#   'Lat': 48.1178,
#   'Lng': -1.2058,
#   'Max Temp': 42.62,
#   'Humidity': 91,
#   'Cloudiness': 27,
#   'Wind Speed': 5.84,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Casper',
#   'Lat': 42.8666,
#   'Lng': -106.3131,
#   'Max Temp': 50.5,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mega',
#   'Lat': 4.05,
#   'Lng': 38.3,
#   'Max Temp': 62.82,
#   'Humidity': 32,
#   'Cloudiness': 76,
#   'Wind Speed': 9.33,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 78.85,
#   'Humidity': 80,
#   'Cloudiness': 61,
#   'Wind Speed': 10.2,
#   'Weather Description': 'broken clouds'},
#  {'City': 'General Roca',
#   'Lat': -39.0333,
#   'Lng': -67.5833,
#   'Max Temp': 83.62,
#   'Humidity': 12,
#   'Cloudiness': 6,
#   'Wind Speed': 25.95,
#   'Weather Description': 'clear sky'},
#  {'City': 'Parma',
#   'Lat': 44.8027,
#   'Lng': 10.329,
#   'Max Temp': 43.95,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Weather Description': 'mist'},
#  {'City': 'San Carlos De Bariloche',
#   'Lat': -41.1456,
#   'Lng': -71.3082,
#   'Max Temp': 61.25,
#   'Humidity': 25,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Weather Description': 'few clouds'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 28.87,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 39.12,
#   'Weather Description': 'light snow'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 65.14,
#   'Humidity': 59,
#   'Cloudiness': 89,
#   'Wind Speed': 8.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nurota',
#   'Lat': 40.5614,
#   'Lng': 65.6886,
#   'Max Temp': 32.09,
#   'Humidity': 76,
#   'Cloudiness': 8,
#   'Wind Speed': 6.58,
#   'Weather Description': 'clear sky'},
#  {'City': 'Danilov',
#   'Lat': 58.1908,
#   'Lng': 40.1717,
#   'Max Temp': 18.9,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.48,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -18,
#   'Humidity': 100,
#   'Cloudiness': 95,
#   'Wind Speed': 4.45,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Maues',
#   'Lat': -3.3836,
#   'Lng': -57.7186,
#   'Max Temp': 76.33,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pontes E Lacerda',
#   'Lat': -15.2261,
#   'Lng': -59.3353,
#   'Max Temp': 76.06,
#   'Humidity': 94,
#   'Cloudiness': 96,
#   'Wind Speed': 6.04,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 56.19,
#   'Humidity': 79,
#   'Cloudiness': 55,
#   'Wind Speed': 14.79,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 81.64,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 10.94,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 15.75,
#   'Humidity': 68,
#   'Cloudiness': 45,
#   'Wind Speed': 11.92,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 10.35,
#   'Humidity': 61,
#   'Cloudiness': 98,
#   'Wind Speed': 11.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sergeyevka',
#   'Lat': 53.88,
#   'Lng': 67.4158,
#   'Max Temp': 9.21,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 76.23,
#   'Humidity': 89,
#   'Cloudiness': 26,
#   'Wind Speed': 12.73,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Soderhamn',
#   'Lat': 61.3037,
#   'Lng': 17.0592,
#   'Max Temp': 27.99,
#   'Humidity': 69,
#   'Cloudiness': 6,
#   'Wind Speed': 12.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 84.02,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Greymouth',
#   'Lat': -42.4667,
#   'Lng': 171.2,
#   'Max Temp': 66.99,
#   'Humidity': 64,
#   'Cloudiness': 58,
#   'Wind Speed': 1.68,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -30.15,
#   'Humidity': 92,
#   'Cloudiness': 17,
#   'Wind Speed': 2.53,
#   'Weather Description': 'few clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 71.69,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Samoded',
#   'Lat': 63.6083,
#   'Lng': 40.5111,
#   'Max Temp': 10.67,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.83,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 78.87,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 67.8,
#   'Humidity': 65,
#   'Cloudiness': 7,
#   'Wind Speed': 20.07,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bardiyah',
#   'Lat': 31.7561,
#   'Lng': 25.0865,
#   'Max Temp': 56.39,
#   'Humidity': 70,
#   'Cloudiness': 59,
#   'Wind Speed': 24.74,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 82.08,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Maceio',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 85.44,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 31.35,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 8.93,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Shestakovo',
#   'Lat': 56.4915,
#   'Lng': 103.96,
#   'Max Temp': -1.91,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.42,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 70.38,
#   'Humidity': 89,
#   'Cloudiness': 21,
#   'Wind Speed': 1.68,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kamariotissa',
#   'Lat': 40.4833,
#   'Lng': 25.4667,
#   'Max Temp': 41.02,
#   'Humidity': 52,
#   'Cloudiness': 98,
#   'Wind Speed': 12.21,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -25.06,
#   'Humidity': 99,
#   'Cloudiness': 82,
#   'Wind Speed': 2.71,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 77.65,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Weather Description': 'light rain'},
#  {'City': 'Rondonopolis',
#   'Lat': -16.4708,
#   'Lng': -54.6356,
#   'Max Temp': 72.61,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Weather Description': 'light rain'},
#  {'City': 'Piney Green',
#   'Lat': 34.716,
#   'Lng': -77.3202,
#   'Max Temp': 46.27,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 8.98,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 44.31,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 8.44,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 21.85,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': -22.16,
#   'Humidity': 99,
#   'Cloudiness': 68,
#   'Wind Speed': 3.42,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 84.29,
#   'Humidity': 88,
#   'Cloudiness': 6,
#   'Wind Speed': 10.4,
#   'Weather Description': 'clear sky'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 76.71,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 57.4,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind Speed': 18.68,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Oriximina',
#   'Lat': -1.7656,
#   'Lng': -55.8661,
#   'Max Temp': 79.39,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 4.27,
#   'Weather Description': 'light rain'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 75.25,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': -1.01,
#   'Humidity': 64,
#   'Cloudiness': 53,
#   'Wind Speed': 7.83,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 52.29,
#   'Humidity': 68,
#   'Cloudiness': 89,
#   'Wind Speed': 19.39,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 78.84,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': -1.21,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 9.31,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 63.81,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 4.9,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 61.3,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 19.46,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 83.73,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 23.09,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 77.56,
#   'Humidity': 12,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Parbatipur',
#   'Lat': 25.6649,
#   'Lng': 88.9247,
#   'Max Temp': 58.1,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.23,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 76.68,
#   'Humidity': 78,
#   'Cloudiness': 93,
#   'Wind Speed': 17.11,
#   'Weather Description': 'light rain'},
#  {'City': 'Zhanakorgan',
#   'Lat': 43.9098,
#   'Lng': 67.2495,
#   'Max Temp': 24.91,
#   'Humidity': 71,
#   'Cloudiness': 61,
#   'Wind Speed': 7.78,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saveh',
#   'Lat': 35.0213,
#   'Lng': 50.3566,
#   'Max Temp': 39.99,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Weather Description': 'clear sky'},
#  {'City': 'Jennings',
#   'Lat': 38.7192,
#   'Lng': -90.2604,
#   'Max Temp': 41.2,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -13.88,
#   'Humidity': 96,
#   'Cloudiness': 83,
#   'Wind Speed': 8.9,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 72.01,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bintulu',
#   'Lat': 3.1667,
#   'Lng': 113.0333,
#   'Max Temp': 75.61,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Weather Description': 'thunderstorm'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 100.92,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 6.31,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Pedro',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 78.31,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 75.83,
#   'Humidity': 75,
#   'Cloudiness': 95,
#   'Wind Speed': 16.04,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 60.76,
#   'Humidity': 91,
#   'Cloudiness': 78,
# ...
#   'Wind Speed': 11.61,
#   'Weather Description': 'few clouds'},
#  {'City': 'Soderhamn',
#   'Country': 'SE',
#   'Lat': 61.3037,
#   'Lng': 17.0592,
#   'Max Temp': 26.98,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 11.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Acapulco',
#   'Country': 'MX',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 84.02,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Weather Description': 'few clouds'},
#  {'City': 'Greymouth',
#   'Country': 'NZ',
#   'Lat': -42.4667,
#   'Lng': 171.2,
#   'Max Temp': 69.64,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 5.39,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -29.85,
#   'Humidity': 94,
#   'Cloudiness': 16,
#   'Wind Speed': 2.64,
#   'Weather Description': 'few clouds'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 69.89,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Samoded',
#   'Country': 'RU',
#   'Lat': 63.6083,
#   'Lng': 40.5111,
#   'Max Temp': 10.11,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Weather Description': 'light snow'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 78.87,
#   'Humidity': 73,
#   'Cloudiness': 47,
#   'Wind Speed': 14.97,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 63.43,
#   'Humidity': 70,
#   'Cloudiness': 4,
#   'Wind Speed': 18.39,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bardiyah',
#   'Country': 'LY',
#   'Lat': 31.7561,
#   'Lng': 25.0865,
#   'Max Temp': 55.87,
#   'Humidity': 71,
#   'Cloudiness': 37,
#   'Wind Speed': 19.66,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint-Georges',
#   'Country': 'GD',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 80.28,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Maceio',
#   'Country': 'BR',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 81.84,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Weather Description': 'few clouds'},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 29.7,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 5.1,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Shestakovo',
#   'Country': 'RU',
#   'Lat': 56.4915,
#   'Lng': 103.96,
#   'Max Temp': -2.06,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.35,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 82.06,
#   'Humidity': 73,
#   'Cloudiness': 18,
#   'Wind Speed': 7,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kamariotissa',
#   'Country': 'GR',
#   'Lat': 40.4833,
#   'Lng': 25.4667,
#   'Max Temp': 42.82,
#   'Humidity': 57,
#   'Cloudiness': 99,
#   'Wind Speed': 6.71,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -25.17,
#   'Humidity': 100,
#   'Cloudiness': 67,
#   'Wind Speed': 2.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Gamba',
#   'Country': 'GA',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 77.54,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rondonopolis',
#   'Country': 'BR',
#   'Lat': -16.4708,
#   'Lng': -54.6356,
#   'Max Temp': 71.64,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.67,
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Piney Green',
#   'Country': 'US',
#   'Lat': 34.716,
#   'Lng': -77.3202,
#   'Max Temp': 44.89,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 10.78,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 44.96,
#   'Humidity': 79,
#   'Cloudiness': 95,
#   'Wind Speed': 7,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 8.44,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': -19.3,
#   'Humidity': 99,
#   'Cloudiness': 60,
#   'Wind Speed': 3.13,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 76.55,
#   'Humidity': 90,
#   'Cloudiness': 21,
#   'Wind Speed': 7.16,
#   'Weather Description': 'few clouds'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 78.51,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Weather Description': 'light rain'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 59.4,
#   'Humidity': 40,
#   'Cloudiness': 66,
#   'Wind Speed': 8.25,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Oriximina',
#   'Country': 'BR',
#   'Lat': -1.7656,
#   'Lng': -55.8661,
#   'Max Temp': 75.13,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 2.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 73.45,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 0.45,
#   'Humidity': 66,
#   'Cloudiness': 70,
#   'Wind Speed': 7.83,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 50.92,
#   'Humidity': 68,
#   'Cloudiness': 94,
#   'Wind Speed': 19.55,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 82.42,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Weather Description': 'few clouds'},
#  {'City': 'Turukhansk',
#   'Country': 'RU',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': -0.47,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 10.13,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 71.8,
#   'Humidity': 84,
#   'Cloudiness': 91,
#   'Wind Speed': 4.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 59.13,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tual',
#   'Country': 'ID',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 84.07,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 20,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 74.39,
#   'Humidity': 13,
#   'Cloudiness': 100,
#   'Wind Speed': 10.63,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Parbatipur',
#   'Country': 'BD',
#   'Lat': 25.6649,
#   'Lng': 88.9247,
#   'Max Temp': 56.86,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 2.73,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hobyo',
#   'Country': 'SO',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 76.57,
#   'Humidity': 79,
#   'Cloudiness': 96,
#   'Wind Speed': 16.17,
#   'Weather Description': 'light rain'},
#  {'City': 'Zhanakorgan',
#   'Country': 'KZ',
#   'Lat': 43.9098,
#   'Lng': 67.2495,
#   'Max Temp': 24.28,
#   'Humidity': 76,
#   'Cloudiness': 67,
#   'Wind Speed': 8.7,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saveh',
#   'Country': 'IR',
#   'Lat': 35.0213,
#   'Lng': 50.3566,
#   'Max Temp': 38.39,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 7.63,
#   'Weather Description': 'clear sky'},
#  {'City': 'Jennings',
#   'Country': 'US',
#   'Lat': 38.7192,
#   'Lng': -90.2604,
#   'Max Temp': 39.15,
#   'Humidity': 56,
#   'Cloudiness': 79,
#   'Wind Speed': 1.99,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -15.34,
#   'Humidity': 95,
#   'Cloudiness': 86,
#   'Wind Speed': 8.84,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 70.21,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bintulu',
#   'Country': 'MY',
#   'Lat': 3.1667,
#   'Lng': 113.0333,
#   'Max Temp': 73.81,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Country': 'AR',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 86.63,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 5.12,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Pedro',
#   'Country': 'PH',
#   'Lat': 14.35,
#   'Lng': 121.0167,
#   'Max Temp': 78.1,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 1.14,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 75.2,
#   'Humidity': 77,
#   'Cloudiness': 97,
#   'Wind Speed': 15.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 63.84,
#   'Humidity': 84,
#   'Cloudiness': 85,
#   'Wind Speed': 4.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Acarau',
#   'Country': 'BR',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 77.2,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.45,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port-Cartier',
#   'Country': 'CA',
#   'Lat': 50.0334,
#   'Lng': -66.8654,
#   'Max Temp': 9.75,
#   'Humidity': 81,
#   'Cloudiness': 77,
#   'Wind Speed': 9.93,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Matay',
#   'Country': 'EG',
#   'Lat': 28.419,
#   'Lng': 30.7792,
#   'Max Temp': 50.5,
#   'Humidity': 50,
#   'Cloudiness': 15,
#   'Wind Speed': 7.67,
#   'Weather Description': 'few clouds'},
#  {'City': 'Quatis',
#   'Country': 'BR',
#   'Lat': -22.4072,
#   'Lng': -44.2581,
#   'Max Temp': 71.19,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 1.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Poum',
#   'Country': 'NC',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 80.44,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 9.04,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Jose',
#   'Country': 'US',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 67.59,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Weather Description': 'haze'},
#  {'City': 'Karratha',
#   'Country': 'AU',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 83.79,
#   'Humidity': 60,
#   'Cloudiness': 69,
#   'Wind Speed': 17.11,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Minot',
#   'Country': 'US',
#   'Lat': 48.2325,
#   'Lng': -101.2963,
#   'Max Temp': 32.99,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Brewster',
#   'Country': 'US',
#   'Lat': 41.3973,
#   'Lng': -73.6171,
#   'Max Temp': 23.59,
#   'Humidity': 56,
#   'Cloudiness': 19,
#   'Wind Speed': 2.57,
#   'Weather Description': 'few clouds'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': -0.62,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Moose Factory',
#   'Country': 'CA',
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': -5.8,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Graaff-Reinet',
#   'Country': 'ZA',
#   'Lat': -32.2522,
#   'Lng': 24.5308,
#   'Max Temp': 74.91,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 2.1,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kropotkin',
#   'Country': 'RU',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 30.45,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Weather Description': 'light snow'},
#  {'City': 'Levelland',
#   'Country': 'US',
#   'Lat': 33.5873,
#   'Lng': -102.378,
#   'Max Temp': 61.2,
#   'Humidity': 22,
#   'Cloudiness': 100,
#   'Wind Speed': 10.87,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tukrah',
#   'Country': 'LY',
#   'Lat': 32.5341,
#   'Lng': 20.5791,
#   'Max Temp': 55.27,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 17.47,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Santiago De Cao',
#   'Country': 'PE',
#   'Lat': -7.9589,
#   'Lng': -79.2392,
#   'Max Temp': 68.13,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Weather Description': 'fog'},
#  {'City': 'Suez',
#   'Country': 'EG',
#   'Lat': 29.9737,
#   'Lng': 32.5263,
#   'Max Temp': 53.89,
#   'Humidity': 45,
#   'Cloudiness': 17,
#   'Wind Speed': 5.08,
#   'Weather Description': 'few clouds'},
#  {'City': 'Florida',
#   'Country': 'US',
#   'Lat': 28.7505,
#   'Lng': -82.5001,
#   'Max Temp': 56.03,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Weather Description': 'clear sky'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 6.96,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Weather Description': 'few clouds'},
#  {'City': 'Itoman',
#   'Country': 'JP',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 59.02,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Praia',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 70.34,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 78.89,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Weather Description': 'few clouds'},
#  {'City': 'Elizabeth City',
#   'Country': 'US',
#   'Lat': 36.2946,
#   'Lng': -76.2511,
#   'Max Temp': 36.01,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Brunsbuttel',
#   'Country': 'DE',
#   'Lat': 53.9,
#   'Lng': 9.15,
#   'Max Temp': 39.45,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Teguajinal',
#   'Country': 'HN',
#   'Lat': 15.3667,
#   'Lng': -86.6,
#   'Max Temp': 66.85,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Osoyoos',
#   'Country': 'CA',
#   'Lat': 49.0331,
#   'Lng': -119.4524,
#   'Max Temp': 33.33,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jiayuguan',
#   'Country': 'CN',
#   'Lat': 39.8167,
#   'Lng': 98.3,
#   'Max Temp': 15.44,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dolores',
#   'Country': 'AR',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 73.96,
#   'Humidity': 62,
#   'Cloudiness': 32,
#   'Wind Speed': 7.67,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Wilmington',
#   'Country': 'US',
#   'Lat': 34.2257,
#   'Lng': -77.9447,
#   'Max Temp': 46.85,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 65.86,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Fort-Shevchenko',
#   'Country': 'KZ',
#   'Lat': 44.5086,
#   'Lng': 50.263,
#   'Max Temp': 37.6,
#   'Humidity': 82,
#   'Cloudiness': 92,
#   'Wind Speed': 6.85,
#   'Weather Description': 'overcast clouds'},
#  ...]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                   Ahipara -35.1667  173.1667     67.33        78
# 1                     Vaini -21.2000 -175.2000     79.88        78
# 2                  Lorengau  -2.0226  147.2712     79.09        83
# 3                   Ushuaia -54.8000  -68.3000     47.86        61
# 4  Sao Jose Da Coroa Grande  -8.8978  -35.1478     81.77        75
# 5                   Ahipara -35.1667  173.1667     71.65        65
# 6                     Vaini -21.2000 -175.2000     79.81        78
# 7                  Lorengau  -2.0226  147.2712     78.30        87
# 8                   Ushuaia -54.8000  -68.3000     47.86        61
# 9  Sao Jose Da Coroa Grande  -8.8978  -35.1478     80.26        79
#
#    Cloudiness  Wind Speed      Weather Description Country
# 0         100       11.01          overcast clouds     NaN
# 1         100       13.13            moderate rain     NaN
# 2         100       11.14          overcast clouds     NaN
# 3          75       28.77  light intensity drizzle     NaN
# 4          99       10.22          overcast clouds     NaN
# 5          95       12.35          overcast clouds     NaN
# 6         100       12.06               light rain     NaN
# 7         100       12.01          overcast clouds     NaN
# 8          75       28.77  light intensity drizzle     NaN
# 9          99       10.11          overcast clouds     NaN

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
